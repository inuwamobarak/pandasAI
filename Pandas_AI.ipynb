# %% [markdown]
# <a href="https://colab.research.google.com/github/inuwamobarak/pandasAI/blob/main/Pandas_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandasai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.7/797.7 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: ipython
# ...

# %%
import pandas as pd
from pandasai import PandasAI # PandasAI
import seaborn as sns # For charts

iris = sns.load_dataset('iris') # iris inbuilt dataset from seaborn
iris.head() # Viewing first rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Sample DataFrame
df = iris

# Instantiating an LLM
from pandasai.llm.openai import OpenAI

# Assigning API key
llm = OpenAI(api_token="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")

# %% [markdown]
# ## Conversational Query

# %%
pandas_ai = PandasAI(llm)
pandas_ai.run(df, prompt='Which is the most common specie?')
# Out:
# 'Oh, the most common specie is actually setosa!'

# %%
pandas_ai = PandasAI(llm)
pandas_ai.run(df, prompt='What is the  average of sepal_length?')
# Out:
# 'The average sepal length of the dataset is 5.84.'

# %%
pandas_ai = PandasAI(llm)
pandas_ai.run(df, prompt='What is the  average of sepal_width?')
# Out:
# 'The average sepal width is 3.0573333333333337.'

# %%
pandas_ai = PandasAI(llm)
pandas_ai.run(df, prompt='Which is the most common petal_length?')
# Out:
# 'Based on the data provided, the most common petal_length is 1.4.'

# %%
response = pandas_ai.run(
    df,
    "Plot the histogram of the entries",
)
print(response)
# Out:
# Sure, here's a histogram of the entries in the dataset. It shows the distribution of values for each variable, including sepal length, sepal width, petal length, petal width, and species. The histogram is a useful way to visualize the data and see any patterns or trends that may exist.

# %%
response = pandas_ai.run(
    df,
    "Perform scattered plot of sepal_length and sepal_width",
)
print(response)
# Out:
# Sure! To create a scattered plot of sepal_length and sepal_width, we can use the data provided in the table. The table includes columns for sepal_length, sepal_width, petal_length, petal_width, and species. We can focus on just the sepal_length and sepal_width columns to create the plot.

# %%
response = pandas_ai.run(
    df,
    "Plot a scattered plot of sepal_length and sepal_width for the species showing the species as key",
)
print(response)
# Out:
# Sure, I can help you with that! To plot a scattered plot of sepal_length and sepal_width for the species showing the species as key, we can use a Python library like Matplotlib or Seaborn. This will allow us to visualize the relationship between these two variables and also differentiate the species using different colors or markers. Would you like me to write the code for you?
